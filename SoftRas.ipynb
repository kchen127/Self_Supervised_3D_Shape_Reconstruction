# %%
try:
    from google.colab import drive
    drive.mount('/content/drive')
except:
    print("Mounting Failed.")
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/DL_Project/
# Out:
# /content/drive/MyDrive/DL_Project

# %%
#!git clone https://github.com/ShichenLiu/SoftRas.git

# %% [markdown]
# # Setup

# %%
#Set Up
# !python setup.py install
# Out:
# running install
# /usr/lib/python3.10/distutils/cmd.py:62: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/lib/python3.10/distutils/cmd.py:62: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
# ...

# %%
#Download and Unzip Dataset
# !bash examples/recon/download_dataset.sh

# %% [markdown]
# # Train

# %%
# !python model/train.py -cls=02691156,04379243,03636649 -ne=10 -se=5
# !python model/train.py -le=0 -ne=100 -se=20 -cls=02691156,02958343,03001627,03636649,04379243,04530566
# Out:
# Loading dataset: 100% 6/6 [00:49<00:00,  8.30s/it]
# Loading dataset: 100% 6/6 [00:13<00:00,  2.17s/it]
# Epoch 1/100
# Mean Training Loss: 0.3540965676669118
# Mean Training IOU: 0.3636130148125741
# Mean Validation Loss: 0.3081730808203037
# Mean Validation IOU: 0.4076499208372144
# Epoch 2/100
# Mean Training Loss: 0.2912884668715076
# Mean Training IOU: 0.4254603855790403
# Mean Validation Loss: 0.27859428312916024
# Mean Validation IOU: 0.44068260663205644
# Epoch 3/100
# Mean Training Loss: 0.2742052323040126
# Mean Training IOU: 0.4450906141103301
# Mean Validation Loss: 0.26477192542873895
# Mean Validation IOU: 0.4545073686089674
# Epoch 4/100
# Mean Training Loss: 0.2626103591892659
# Mean Training IOU: 0.45906858796322836
# Mean Validation Loss: 0.25978923302430373
# Mean Validation IOU: 0.46335952431341526
# Epoch 5/100
# Mean Training Loss: 0.25298304177303166
# Mean Training IOU: 0.4704463072052683
# Mean Validation Loss: 0.255197858523864
# ...

# %%
#用于在更改py文件后刷新文件
# %cd ..
# %cd DL_Project
# Out:
# /content/drive/.shortcut-targets-by-id/1Pa2PHGdcCKPI4tZjIGm_KVpuhF3dOgBm
# /content/drive/.shortcut-targets-by-id/1Pa2PHGdcCKPI4tZjIGm_KVpuhF3dOgBm/DL_Project
